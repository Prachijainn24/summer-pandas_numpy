# %% [markdown]
# <a href="https://colab.research.google.com/github/Prachijainn24/summer-pandas_numpy/blob/main/day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#introduction to pandas
#ds in pandas  - series, dataframes
#creates multi dimensional array

# %%
#series- 1d array shows only values not column name

# %%
import pandas as pd
a=pd.Series( [1,23,45,67,90] )
print(a)
# Out:
# 0     1
# 1    23
# 2    45
# 3    67
# 4    90
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
#dataframe-it is multi dimensional array and it has values with column name
a = {
     "Name":['sam','raj','rahul','gaurav'],
     "Domain":['D.S','D.E','D.S','full stack'],
     "Duration":[10,15,45,30]
}

# %%
df=pd.DataFrame(a)
df
# Out:
#      Name      Domain  Duration
# 0     sam         D.S        10
# 1     raj         D.E        15
# 2   rahul         D.S        45
# 3  gaurav  full stack        30

# %%
df.to_csv("intern_student.csv")

# %%
df.to_csv("/content/intern_student.csv")

# %%
df=pd.read_csv('/content/best buses.csv')
df
# Out:
#                                                 Buses  \
# 0                                             FlixBus
# 1                           Shree Raj Akanshi travels
# 2                                Vikas Travels Jaipur
# 3                             PAL BUS(Patel Travels®)
# 4   Shri Krishna Travels ( Jai Shree Ganesh Yatra ...
# 5                                        Zingbus Plus
# 6                          Ram Dalal Holidays Pvt Ltd
# 7                                    Maharani Travels
# 8                                   Mahalaxmi Travels
# 9                                             FlixBus
# 10                                       Zingbus Plus
# 11                                     NAVEEN TRAVELS
# 12                                  Mahalaxmi Travels
# 13                                     NAVEEN TRAVELS
# 14                                  Mahalaxmi Travels
# 15  Shri Krishna Travels ( Jai Shree Ganesh Yatra ...
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/best_mobiles.csv')
df
# Out:
#                                              Mobiles  ratings  \
# 0         CMF by Nothing Phone 2 Pro (White, 128 GB)      4.4
# 1   realme P3 Ultra 5G (Glowing Lunar White, 256 GB)      4.4
# 2               POCO C75 5G (Silver Stardust, 64 GB)      4.3
# 3                    POCO C75 5G (Aqua Bliss, 64 GB)      4.3
# 4             Motorola g45 5G (Viva Magenta, 128 GB)      4.3
# 5        SAMSUNG Galaxy F06 5G (Bahama Blue, 128 GB)      4.2
# 6               MOTOROLA g35 5G (Leaf Green, 128 GB)      4.2
# 7           Motorola g45 5G (Brilliant Blue, 128 GB)      4.3
# 8            Motorola g45 5G (Pink Lavender, 128 GB)      4.3
# 9                    POCO M7 5G (Mint Green, 128 GB)      4.1
# 10          Motorola g45 5G (Brilliant Blue, 128 GB)      4.3
# 11                   POCO M7 5G (Ocean Blue, 128 GB)      4.1
# 12       SAMSUNG Galaxy F06 5G (Bahama Blue, 128 GB)      4.1
# 13          MOTOROLA g35 5G (Midnight Black, 128 GB)      4.2
# ...
